# %%
from tes_controller import DeviceController
import time

# %%
ctrl = DeviceController.from_config("config_example.yaml")

# %%
ctrl.flux_ramp_set(1024)
# Out:
# {'command': 'DAC_SET', 'value': 1024, 'message': 'Main DAC value set'}
